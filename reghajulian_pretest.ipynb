# %% [markdown]
# # Pretest Data Science
# Author : Regha Julian Pradhana
# <br> Email: regha_j_pradhana@telkomsel.co.id

# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
churn = pd.read_csv('D:/Online/OneDrive - PT Telekomunikasi Selular/Postpaid/Data Science/Dataset Pretest/churn.csv')
churn.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
#row
print("baris:",len(churn))
#column
print("kolom:",len(churn.columns))
# Out:
# baris: 5000
# kolom: 21

# %%
churn_clean=churn.dropna()
#row
print("baris:",len(churn_clean))
#column
print("kolom:",len(churn_clean.columns))
# Out:
# baris: 5000
# kolom: 21

# %%
# unique state
len(churn_clean.state.unique())
# Out:
# 51

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %% [markdown]
# ### 1. What is the absolute correlation value of all numeric variables towards class?

# %%
# Sort from higher correlation to lower, and choose top 7 (include class)
abs(churn[numeric_variable].corr()['class']).sort_values(ascending=False).head(7)
# Out:
# class                            1.000000
# international_plan               0.259123
# number_customer_service_calls    0.212564
# total_day_minutes                0.207705
# total_day_charge                 0.207700
# voice_mail_plan                  0.110698
# number_vmail_messages            0.097633
# Name: class, dtype: float64

# %% [markdown]
# ### 2. Top 5 State with highest churner!

# %%
churn_yes = churn[churn['class']==1]
churn_yes['state'].value_counts().head(5)
# Out:
# 31    28
# 43    26
# 47    24
# 49    22
# 20    21
# Name: state, dtype: int64

# %%
churn_corr = churn[['class','international_plan','number_customer_service_calls','total_day_minutes','total_day_charge',
                   'voice_mail_plan','number_vmail_messages']]
churn_corr.groupby('class').mean().sort_values(['total_day_minutes','total_day_charge'], ascending=False).head()
# Out:
#        international_plan  number_customer_service_calls  total_day_minutes  \
# class
# 1                0.281471                       2.254597         207.870580
# 0                0.063825                       1.457722         175.746564
#
#        total_day_charge  voice_mail_plan  number_vmail_messages
# class
# 1             35.338416         0.144272               4.496464
# 0             29.877494         0.284416               8.291870

# %% [markdown]
# ### 3. Most Correlated Variables?

# %%
churn_corr_variabel = churn[['class','total_day_minutes','total_day_charge']]
churn_corr_variabel.corr(method='pearson')
# Out:
#                       class  total_day_minutes  total_day_charge
# class              1.000000           0.207705            0.2077
# total_day_minutes  0.207705           1.000000            1.0000
# total_day_charge   0.207700           1.000000            1.0000

# %% [markdown]
# ### 4. What is the Average Number Customer Service Calls?

# %%
churn_number_customer_service_calls = churn[['class','number_customer_service_calls']]
churn_number_customer_service_calls.groupby('class').mean().sort_values('number_customer_service_calls', ascending=False).head()
# Out:
#        number_customer_service_calls
# class
# 1                           2.254597
# 0                           1.457722

# %% [markdown]
# ### 5. What is the Total International Plan for each class?

# %%
pd.crosstab(churn['class'], churn['international_plan'], margins=True)
# Out:
# international_plan     0    1   All
# class
# 0                   4019  274  4293
# 1                    508  199   707
# All                 4527  473  5000
